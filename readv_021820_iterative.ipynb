# %%
# uses conda environment gpflow6_0

# #!/anaconda3/envs/gpflow6_0/env/bin/python

from memory_profiler import profile

# generic
import numpy as np
import pandas as pd
import xarray as xr
import dask.array as da
import scipy.io as io
from itertools import product
import glob
import time
import os

# plotting
from matplotlib import pyplot as plt
from matplotlib import colors
from matplotlib.colors import Normalize
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.lines import Line2D
import seaborn as sns

# gpflow
import gpflow as gpf
from gpflow.utilities import print_summary
from gpflow.logdensities import multivariate_normal
from gpflow.kernels import Kernel
from gpflow.mean_functions import MeanFunction
from typing import Optional, Tuple, List
from gpflow.config import default_jitter

# tensorflow
import tensorflow as tf
from tensorflow_probability import bijectors as tfb

# set the colormap and centre the colorbar
class MidpointNormalize(Normalize):
    """Normalise the colorbar.  e.g. norm=MidpointNormalize(mymin, mymax, 0.)"""
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y), np.isnan(value))


####################  Initialize parameters #######################
#################### ---------------------- #######################

ice_models = ['d6g_h6g_', 'glac1d_']
lith_thicknesses = ['l96C', 'l71C']

for i, ice_model in enumerate(ice_models):
    for k, lith_thickness in enumerate(lith_thicknesses):
        plotting = 'false'
        decomp = 'false'
        ice_model = ice_model # 'd6g_h6g_' # 'glac1d_' #   #
        lith_thickness = lith_thickness # 'l96'  # 'l90C'
        model = ice_model + lith_thickness
        place = 'fennoscandia'

        locs = {
            'england': [-12, 2, 50, 60],
            'easternhem': [50, 178, -45, 80],
            'westernhem': [-175, 30, -80, 75],
            'world': [-179.8, 179.8, -89.8, 89.8],
            'namerica': [-150, -20, 10, 75],
            'eastcoast': [-88, -65, 15, 40],
            'europe': [-20, 15, 35, 70],
            'atlantic':[-85,10, 25, 60],
            'fennoscandia': [-15, 50, 45, 73],
        }
        extent = locs[place]
        tmax, tmin, tstep = 5550, 4950, 100

        ages_lgm = np.arange(100, 26000, tstep)[::-1]

        #import khan dataset
        path = 'data/GSL_LGM_120519_.csv'

        df = pd.read_csv(path, encoding="ISO-8859-15", engine='python')
        df = df.replace('\s+', '_', regex=True).replace('-', '_', regex=True).\
                applymap(lambda s:s.lower() if type(s) == str else s)
        df.columns = df.columns.str.lower()
        df.rename_axis('index', inplace=True)
        df = df.rename({'latitude': 'lat', 'longitude': 'lon'}, axis='columns')
        dfind, dfterr, dfmar = df[(df.type == 0)
                                  & (df.age > 0)], df[df.type == 1], df[df.type == -1]
        np.sort(list(set(dfind.regionname1)))

        #select location
        df_place = dfind[(dfind.age > tmin) & (dfind.age < tmax) &
                         (dfind.lon > extent[0])
                         & (dfind.lon < extent[1])
                         & (dfind.lat > extent[2])
                         & (dfind.lat < extent[3])][[
                             'lat', 'lon', 'rsl', 'rsl_er_max', 'age'
                         ]]
        # & (df_place.rsl_er_max < 1)
        df_place.shape

        ####################  	Plot locations  	#######################
        #################### ---------------------- #######################

        #get counts by location rounded to nearest 0.1 degree
        df_rnd = df_place.copy()
        df_rnd.lat = np.round(df_rnd.lat, 1)
        df_rnd.lon = np.round(df_rnd.lon, 1)
        dfcounts_place = df_rnd.groupby(
            ['lat', 'lon']).count().reset_index()[['lat', 'lon', 'rsl', 'age']]

        #plot
        fig = plt.figure(figsize=(10, 7))
        ax = plt.subplot(1, 1, 1, projection=ccrs.PlateCarree())

        ax.set_extent(extent)
        ax.coastlines(resolution='110m', linewidth=1, zorder=2)
        ax.add_feature(cfeature.OCEAN, zorder=0)
        ax.add_feature(cfeature.LAND, color='palegreen', zorder=1)
        ax.add_feature(cfeature.BORDERS, linewidth=0.5, zorder=3)
        ax.gridlines(linewidth=1, color='white', alpha=0.5, zorder=4)
        scat = ax.scatter(dfcounts_place.lon,
                          dfcounts_place.lat,
                          s=dfcounts_place.rsl * 70,
                          c='lightsalmon',
                          vmin=-20,
                          vmax=20,
                          cmap='coolwarm',
                          edgecolor='k',
                          linewidths=1,
                          transform=ccrs.PlateCarree(),
                          zorder=5)
        size = Line2D(range(4),
                      range(4),
                      color="black",
                      marker='o',
                      linewidth=0,
                      linestyle='none',
                      markersize=16,
                      markerfacecolor="lightsalmon")
        labels = ['RSL datapoint location']
        leg = plt.legend([size],
                         labels,
                         loc='lower left',
                         bbox_to_anchor=(0.00, 0.00),
                         prop={'size': 20},
                         fancybox=True)
        leg.get_frame().set_edgecolor('k')
        ax.set_title('')

        ####################  Make 3D fingerprint  #######################
        #################### ---------------------- #######################

        filename = 'data/WAISreadvance_VM5_6ka_1step.mat'

        waismask = io.loadmat(filename, squeeze_me=True)
        ds_mask = xr.Dataset({'rsl': (['lat', 'lon', 'age'], waismask['RSL'])},
                             coords={
                                 'lon': waismask['lon_out'],
                                 'lat': waismask['lat_out'],
                                 'age': np.round(waismask['ice_time_new'])
                             })
        fingerprint = ds_mask.sel(age=ds_mask.age[0])


        def make_fingerprint(start, end, maxscale):

            #palindromic scaling vector
            def palindrome(maxscale, ages):
                """ Make palindrome scale 0-maxval with number of steps. """
                half = np.linspace(0, maxscale, 1 + (len(ages) - 1) // 2)
                scalefactor = np.concatenate([half, half[::-1]])
                return scalefactor

            ages_readv = ages_lgm[(ages_lgm < start) & (ages_lgm >= end)]
            scale = palindrome(maxscale, ages_readv)

            #scale factor same size as ice model ages
            pre = np.zeros(np.where(ages_lgm == start)[0])
            post = np.zeros(len(ages_lgm) - len(pre) - len(scale))

            readv_scale = np.concatenate([pre, scale, post])

            #scale factor into dataarray
            da_scale = xr.DataArray(readv_scale, coords=[('age', ages_lgm)])

            # broadcast fingerprint & scale to same dimensions;
            fingerprint_out, fing_scaled = xr.broadcast(fingerprint.rsl, da_scale)

            # mask fingerprint with scale to get LGM-pres timeseries
            ds_fingerprint = (fingerprint_out *
                              fing_scaled).transpose().to_dataset(name='rsl')

            # scale dataset with fingerprint to LGM-present length & 0-max-0 over x years
            xrlist = []
            for i, key in enumerate(da_scale):
                mask = ds_fingerprint.sel(age=ds_fingerprint.age[i].values) * key
                mask = mask.assign_coords(scale=key,
                                          age=ages_lgm[i]).expand_dims(dim=['age'])
                xrlist.append(mask)
            ds_readv = xr.concat(xrlist, dim='age')

            ds_readv.coords['lon'] = pd.DataFrame((ds_readv.lon[ds_readv.lon >= 180] - 360)- 0.12) \
                                    .append(pd.DataFrame(ds_readv.lon[ds_readv.lon < 180]) + 0.58) \
                                    .reset_index(drop=True).squeeze()
            ds_readv = ds_readv.swap_dims({'dim_0': 'lon'}).drop('dim_0')

            # Add readv to modeled RSL at locations with data
            ##### Need to fix this, as currently slice does not acknowledge new coords #########
            ds_readv = ds_readv.sel(age=slice(tmax, tmin),
                                    lon=slice(df_place.lon.min() + 180 - 2,
                                              df_place.lon.max() + 180 + 2),
                                    lat=slice(df_place.lat.max() + 2,
                                              df_place.lat.min() - 2))
            return ds_readv


        #Make deterministic readvance fingerprint
        start, end = 6100, 3000
        maxscale = 2.25
        ds_readv = make_fingerprint(start, end, maxscale)


        ####################  Build  GIA models 	#######################
        #################### ---------------------- #######################

        #Use either glac1d or ICE6G


        def build_dataset(path, model):
            """download model runs from local directory."""
            path = path
            files = f'{path}*.nc'
            basefiles = glob.glob(files)
            modelrun = [
                key.split('output_', 1)[1][:-3].replace('.', '_')
                for key in basefiles
            ]
            dss = xr.open_mfdataset(files,
                                    chunks=None,
                                    concat_dim='modelrun',
                                    combine='nested')
            lats, lons, times = dss.LAT.values[0], dss.LON.values[
                0], dss.TIME.values[0]
            ds = dss.drop(['LAT', 'LON', 'TIME'])
            ds = ds.assign_coords(lat=lats,
                                  lon=lons,
                                  time=times,
                                  modelrun=modelrun).rename({
                                      'time': 'age',
                                      'RSL': 'rsl'
                                  })
            return ds

        def one_mod(path, names):
            """Organize model runs into xarray dataset."""
            ds1 = build_dataset(path, names[0])
            names = names[1:]
            ds = ds1.chunk({'lat': 10, 'lon': 10})
            for i in range(len(names)):
                temp = build_dataset(names[i])
                temp1 = temp.interp_like(ds1)
                temp1['modelrun'] = temp['modelrun']
                ds = xr.concat([ds, temp1], dim='modelrun')
            ds['age'] = ds['age'] * 1000
            ds = ds.roll(lon=256, roll_coords=True)
            ds.coords['lon'] = pd.DataFrame((ds.lon[ds.lon >= 180] - 360)- 0.12 ) \
                                    .append(pd.DataFrame(ds.lon[ds.lon < 180]) + 0.58) \
                                    .reset_index(drop=True).squeeze()
            ds.coords['lat'] = ds.lat[::-1]
            ds = ds.swap_dims({'dim_0': 'lon'}).drop('dim_0')
            return ds

        #make composite of a bunch of GIA runs, i.e. GIA prior

        if ice_model == 'glac1d_':
            path = f'data/glac1d_/output_{model}'

            #make composite of a bunch of GIA runs, i.e. GIA prior
            ds = one_mod(path, [model])
            ds_sliced = ds.rsl.sel(age=slice(tmax, tmin),
                                   lon=slice(df_place.lon.min() - 2,
                                             df_place.lon.max() + 2),
                                   lat=slice(df_place.lat.min() - 2,
                                             df_place.lat.max() + 2))

        elif ice_model == 'd6g_h6g_':
            path = f'data/d6g_h6g_/output_{model}'

            #make GIA prior std.
            ds = one_mod(path, [model])
            ds_sliced = ds.rsl.sel(age=slice(tmax, tmin),
                                   lon=slice(df_place.lon.min() - 2,
                                             df_place.lon.max() + 2),
                                   lat=slice(df_place.lat.min() - 2,
                                             df_place.lat.max() + 2))

        ds_areastd = ds_sliced.std(dim='modelrun').load().to_dataset().interp(
            age=ds_readv.age, lon=ds_readv.lon, lat=ds_readv.lat)

        # loop through models to calculate GPR log likelihood

        runs = ds.modelrun.values.tolist()

        modrunlist = []
        loglikelist = []
        for i, modelrun in enumerate(runs):

            print('---------------')
            print(f'{modelrun} run number {i}')

            if ice_model == 'glac1d_':
                # make prior RSL 
                ds_area = one_mod(path,
                    [ice_model + lith_thickness]).sel(modelrun=modelrun).rsl.sel(
                        age=slice(tmax, tmin),
                        lon=slice(df_place.lon.min() - 2,
                                  df_place.lon.max() + 2),
                        lat=slice(df_place.lat.min() - 2,
                                  df_place.lat.max() + 2)).load().to_dataset().interp(
                                      age=ds_readv.age, lon=ds_readv.lon, lat=ds_readv.lat)

            else:
                # make prior RSL
                ds_area = one_mod(path,
                    [ice_model + lith_thickness]).sel(modelrun=modelrun).rsl.sel(
                        age=slice(tmax, tmin),
                        lon=slice(df_place.lon.min() - 2,
                                  df_place.lon.max() + 2),
                        lat=slice(df_place.lat.min() - 2,
                                  df_place.lat.max() + 2)).load().to_dataset().interp(
                                      age=ds_readv.age, lon=ds_readv.lon, lat=ds_readv.lat)


            #sample each model at points where we have RSL data
            def ds_select(ds):
                return ds.rsl.sel(age=[row.age],
                                  lon=[row.lon],
                                  lat=[row.lat],
                                  method='nearest').squeeze().values

            #select points at which RSL data exists
            for i, row in df_place.iterrows():
                df_place.loc[i, 'rsl_realresid'] = df_place.rsl[i] - ds_select(ds_area)
                df_place.loc[i, 'rsl_giaprior'] = ds_select(ds_area)
                df_place.loc[i, 'rsl_giaprior_std'] = ds_select(ds_areastd)

            print('number of datapoints = ', df_place.shape)

            ##################	  RUN GP REGRESSION 	#######################
            ##################  --------------------	 ######################
            start = time.time()

            def run_gpr():

                Data = Tuple[tf.Tensor, tf.Tensor]
                likelihood = df_place.rsl_er_max.ravel()**2 # + df_place.rsl_giaprior_std.ravel()**2  # here we define likelihood

                class GPR_diag(gpf.models.GPModel):
                    r"""
                    Gaussian Process Regression.
                    This is a vanilla implementation of GP regression with a pointwise Gaussian
                    likelihood.  Multiple columns of Y are treated independently.
                    The log likelihood of this models is sometimes referred to as the 'marginal log likelihood',
                    and is given by
                    .. math::
                       \log p(\mathbf y \,|\, \mathbf f) =
                            \mathcal N\left(\mathbf y\,|\, 0, \mathbf K + \sigma_n \mathbf I\right)
                    """
                    def __init__(self,
                                 data: Data,
                                 kernel: Kernel,
                                 mean_function: Optional[MeanFunction] = None,
                                 likelihood=likelihood):
                        likelihood = gpf.likelihoods.Gaussian(variance=likelihood)
                        _, y_data = data
                        super().__init__(kernel,
                                         likelihood,
                                         mean_function,
                                         num_latent=y_data.shape[-1])
                        self.data = data

                    def log_likelihood(self):
                        """
                        Computes the log likelihood.
                        """
                        x, y = self.data
                        K = self.kernel(x)
                        num_data = x.shape[0]
                        k_diag = tf.linalg.diag_part(K)
                        s_diag = tf.convert_to_tensor(self.likelihood.variance)
                        jitter = tf.cast(tf.fill([num_data], default_jitter()),
                                         'float64')  # stabilize K matrix w/jitter
                        ks = tf.linalg.set_diag(K, k_diag + s_diag + jitter)
                        L = tf.linalg.cholesky(ks)
                        m = self.mean_function(x)

                        # [R,] log-likelihoods for each independent dimension of Y
                        log_prob = multivariate_normal(y, m, L)
                        return tf.reduce_sum(log_prob)

                    def predict_f(self,
                                  predict_at: tf.Tensor,
                                  full_cov: bool = False,
                                  full_output_cov: bool = False):
                        r"""
                        This method computes predictions at X \in R^{N \x D} input points
                        .. math::
                            p(F* | Y)
                        where F* are points on the GP at new data points, Y are noisy observations at training data points.
                        """
                        x_data, y_data = self.data
                        err = y_data - self.mean_function(x_data)

                        kmm = self.kernel(x_data)
                        knn = self.kernel(predict_at, full=full_cov)
                        kmn = self.kernel(x_data, predict_at)

                        num_data = x_data.shape[0]
                        s = tf.linalg.diag(tf.convert_to_tensor(
                            self.likelihood.variance))  #changed from normal GPR

                        conditional = gpf.conditionals.base_conditional
                        f_mean_zero, f_var = conditional(
                            kmn, kmm + s, knn, err, full_cov=full_cov,
                            white=False)  # [N, P], [N, P] or [P, N, N]
                        f_mean = f_mean_zero + self.mean_function(predict_at)
                        return f_mean, f_var


                def normalize(df):
                    return np.array((df - df.mean()) / df.std()).reshape(len(df), 1)


                def denormalize(y_pred, df):
                    return np.array((y_pred * df.std()) + df.mean())


                def bounded_parameter(low, high, param):
                    """Make parameter tfp Parameter with optimization bounds."""
                    affine = tfb.AffineScalar(shift=tf.cast(low, tf.float64),
                                              scale=tf.cast(high - low, tf.float64))
                    sigmoid = tfb.Sigmoid()
                    logistic = tfb.Chain([affine, sigmoid])
                    parameter = gpf.Parameter(param, transform=logistic, dtype=tf.float64)
                    return parameter


                class HaversineKernel_Matern52(gpf.kernels.Matern52):
                    """
                    Isotropic Matern52 Kernel with Haversine distance instead of euclidean distance.
                    Assumes n dimensional data, with columns [latitude, longitude] in degrees.
                    """
                    def __init__(
                        self,
                        lengthscale=1.0,
                        variance=1.0,
                        active_dims=None,
                    ):
                        super().__init__(
                            active_dims=active_dims,
                            variance=variance,
                            lengthscale=lengthscale,
                        )

                    def haversine_dist(self, X, X2):
                        pi = np.pi / 180
                        f = tf.expand_dims(X * pi, -2)  # ... x N x 1 x D
                        f2 = tf.expand_dims(X2 * pi, -3)  # ... x 1 x M x D
                        d = tf.sin((f - f2) / 2)**2
                        lat1, lat2 = tf.expand_dims(X[:, 0] * pi, -1), \
                                    tf.expand_dims(X2[:, 0] * pi, -2)
                        cos_prod = tf.cos(lat2) * tf.cos(lat1)
                        a = d[:, :, 0] + cos_prod * d[:, :, 1]
                        c = tf.asin(tf.sqrt(a)) * 6371 * 2
                        return c

                    def scaled_squared_euclid_dist(self, X, X2):
                        """
                        Returns (dist(X, X2ᵀ)/lengthscales)².
                        """
                        if X2 is None:
                            X2 = X
                        dist = da.square(self.haversine_dist(X, X2) / self.lengthscale)
                #             dist = tf.convert_to_tensor(dist)
                        return dist


                class HaversineKernel_Matern32(gpf.kernels.Matern32):
                    """
                    Isotropic Matern52 Kernel with Haversine distance instead of euclidean distance.
                    Assumes n dimensional data, with columns [latitude, longitude] in degrees.
                    """
                    def __init__(
                        self,
                        lengthscale=1.0,
                        variance=1.0,
                        active_dims=None,
                    ):
                        super().__init__(
                            active_dims=active_dims,
                            variance=variance,
                            lengthscale=lengthscale,
                        )

                    def haversine_dist(self, X, X2):
                        pi = np.pi / 180
                        f = tf.expand_dims(X * pi, -2)  # ... x N x 1 x D
                        f2 = tf.expand_dims(X2 * pi, -3)  # ... x 1 x M x D
                        d = tf.sin((f - f2) / 2)**2
                        lat1, lat2 = tf.expand_dims(X[:, 0] * pi, -1), \
                                    tf.expand_dims(X2[:, 0] * pi, -2)
                        cos_prod = tf.cos(lat2) * tf.cos(lat1)
                        a = d[:, :, 0] + cos_prod * d[:, :, 1]
                        c = tf.asin(tf.sqrt(a)) * 6371 * 2
                        return c

                    def scaled_squared_euclid_dist(self, X, X2):
                        """
                        Returns (dist(X, X2ᵀ)/lengthscales)².
                        """
                        if X2 is None:
                            X2 = X
                        dist = tf.square(self.haversine_dist(X, X2) / self.lengthscale)
                #             dist = tf.convert_to_tensor(dist) # return to tensorflow
                        return dist


                ########### Section to Run GPR######################
                ##################################3#################

                # Input space, rsl normalized to zero mean, unit variance
                X = np.stack((df_place['lon'], df_place['lat'], df_place['age']), 1)
                RSL = normalize(df_place.rsl_realresid)

                #define kernels  with bounds

#                 k1 = HaversineKernel_Matern32(active_dims=[0, 1])
#                 k1.lengthscale = bounded_parameter(5000, 30000, 10000)  #hemispheric space
#                 k1.variance = bounded_parameter(0.1, 100, 2)

                k1 = gpf.kernels.Matern32(active_dims=[0, 1])
                k1.lengthscale = bounded_parameter(50, 500, 20)  #hemispheric space
                k1.variance = bounded_parameter(0.05, 100, 2)

#                 k2 = HaversineKernel_Matern32(active_dims=[0, 1])
#                 k2.lengthscale = bounded_parameter(10, 5000, 100)  #GIA space
#                 k2.variance = bounded_parameter(0.1, 100, 2)

                k2 = gpf.kernels.Matern32(active_dims=[0,1])
                k2.lengthscale = bounded_parameter(1, 50, 5)  #GIA space
                k2.variance = bounded_parameter(0.05, 100, 2)

                k3 = gpf.kernels.Matern32(active_dims=[2])  #GIA time
                k3.lengthscale = bounded_parameter(8000, 20000, 10000)
                k3.variance = bounded_parameter(0.1, 100, 1)

                k4 = gpf.kernels.Matern32(active_dims=[2])  #shorter time
                k4.lengthscale = bounded_parameter(1, 8000, 1000)
                k4.variance = bounded_parameter(0.1, 100, 1)

                k5 = gpf.kernels.White(active_dims=[2])
                k5.variance = bounded_parameter(0.1, 100, 1)

                kernel = (k1 * k3) + (k2 * k4) + k5

                #build & train model
                m = GPR_diag((X, RSL), kernel=kernel, likelihood=likelihood)
                print('model built, time=', time.time() - start)


                @tf.function(autograph=False)
                def objective():
                    return - m.log_marginal_likelihood()

                o = gpf.optimizers.Scipy()
                o.minimize(objective, variables=m.trainable_variables)
                print('model minimized, time=', time.time() - start)

                # output space
                nout = 50
                lat = np.linspace(min(ds_area.lat), max(ds_area.lat), nout)
                lon = np.linspace(min(ds_area.lon), max(ds_area.lon), nout)
                ages = ages_lgm[(ages_lgm < tmax) & (ages_lgm > tmin)]
                xyt = np.array(list(product(lon, lat, ages)))

                #query model & renormalize data
                y_pred, var = m.predict_f(xyt)
                y_pred_out = denormalize(y_pred, df_place.rsl_realresid)

                #reshape output vectors
                Xlon = np.array(xyt[:, 0]).reshape((nout, nout, len(ages)))
                Xlat = np.array(xyt[:, 1]).reshape((nout, nout, len(ages)))
                Zp = np.array(y_pred_out).reshape(nout, nout, len(ages))
                varp = np.array(var).reshape(nout, nout, len(ages))

                #print kernel details
            #     print_summary(m, fmt='notebook')
                print('time elapsed = ', time.time() - start)

                print('negative log marginal likelihood =',
                      m.neg_log_marginal_likelihood().numpy())


                modrunlist.append(modelrun)
                loglikelist.append(m.neg_log_marginal_likelihood().numpy())



                ##################	  INTERPOLATE MODELS 	#######################
                ##################  --------------------	 ######################

                # turn GPR output into xarray dataarray
                da_zp = xr.DataArray(Zp, coords=[lon, lat, ages],
                                     dims=['lon', 'lat',
                                           'age']).transpose('age', 'lat', 'lon')
                da_varp = xr.DataArray(varp,
                                       coords=[lon, lat, ages],
                                       dims=['lon', 'lat',
                                             'age']).transpose('age', 'lat', 'lon')


                def interp_likegpr(ds):
                    return ds.rsl.load().transpose().interp_like(da_zp)


                #interpolate all models onto GPR grid
                da_giapriorinterp = interp_likegpr(ds_area)
                ds_giapriorinterp = ds_area.interp(age=ages)
                da_giapriorinterpstd = interp_likegpr(ds_areastd)

                # add total prior RSL back into GPR
                da_priorplusgpr = da_zp + da_giapriorinterp

                return ages, da_zp, da_giapriorinterp, da_priorplusgpr, da_varp, modrunlist, loglikelist

            ages, da_zp, da_giapriorinterp, da_priorplusgpr, da_varp, modrunlist, loglikelist = run_gpr()
            ##################	  	 SAVE NETCDFS 	 	#######################
            ##################  --------------------	 ######################

            path_gen = f'{ages[0]}_{ages[-1]}_{model}_{place}'
            da_zp.to_netcdf('output/' + path_gen + '_da_zp')
            da_giapriorinterp.to_netcdf('output/' + path_gen + '_giaprior')
            da_priorplusgpr.to_netcdf('output/' + path_gen + '_posterior')
            da_varp.to_netcdf('output/' + path_gen + '_gp_variance')

            ##################		  PLOT  MODELS 		#######################
            ##################  --------------------	 ######################
            dirName = f'figs/{place}/'
            if not os.path.exists(dirName):
                os.mkdir(dirName)
                print("Directory ", dirName, " Created ")
            else:
                pass
    #             print("Directory ", dirName, " already exists")

            if plotting == 'true':
                for i, age in enumerate(ages):
                    if (age / 500).is_integer():
                        step = (ages[0] - ages[1])
                        df_it = df_place[(df_place.age < age) & (df_place.age > age - step)]
                        resid_it = da_zp.sel(age=slice(age, age - step))
                        rsl, var = df_it.rsl, df_it.rsl_er_max.values**2
                        lat_it, lon_it = df_it.lat, df_it.lon
                        vmin = ds_giapriorinterp.rsl.min().values  # + 10
                        vmax = ds_giapriorinterp.rsl.max().values  # - 40
                        vmin_std = 0
                        vmax_std = 1
                        tmin_it = np.round(age - step, 2)
                        tmax_it = np.round(age, 2)
                        cbarscale = 0.3
                        fontsize = 20
                        cmap = 'coolwarm'
                        cbar_kwargs = {'shrink': cbarscale, 'label': 'RSL (m)'}

                        proj = ccrs.PlateCarree()
                        projection = ccrs.PlateCarree()
                        fig, (ax1, ax2, ax3,
                              ax4) = plt.subplots(1,
                                                  4,
                                                  figsize=(24, 16),
                                                  subplot_kw=dict(projection=projection))

                        # total prior mean + "true" data
                        ax1.coastlines(color='k')
                        pc1 = ds_giapriorinterp.rsl[i].transpose().plot(ax=ax1,
                                                                        transform=proj,
                                                                        cmap=cmap,
                                                                        norm=MidpointNormalize(
                                                                            vmin, vmax, 0),
                                                                        add_colorbar=False,
                                                                        extend='both')
                        cbar = fig.colorbar(pc1,
                                            ax=ax1,
                                            shrink=.3,
                                            label='RSL (m)',
                                            extend='both')
                        scat = ax1.scatter(lon_it,
                                           lat_it,
                                           s=80,
                                           c=rsl,
                                           edgecolor='k',
                                           vmin=vmin,
                                           vmax=vmax,
                                           norm=MidpointNormalize(vmin, vmax, 0),
                                           cmap=cmap)
                        ax1.set_title(f'{np.round(ds_giapriorinterp.rsl[i].age.values, -1)} yrs',
                                      fontsize=fontsize)
                        #         ax1.set_extent(extent_)

                        # Learned difference between prior and "true" data
                        ax2.coastlines(color='k')
                        pc = da_zp[i, :, :].plot(ax=ax2,
                                                 transform=proj,
                                                 cmap=cmap,
                                                 extend='both',
                                                 norm=MidpointNormalize(
                                                     resid_it.min(), resid_it.max(), 0),
                                                 add_colorbar=False)
                        cbar = fig.colorbar(pc,
                                            ax=ax2,
                                            shrink=.3,
                                            label='RSL (m)',
                                            extend='both')
                        scat = ax2.scatter(lon_it,
                                           lat_it,
                                           s=80,
                                           facecolors='k',
                                           cmap=cmap,
                                           edgecolor='k',
                                           transform=proj,
                                           norm=MidpointNormalize(resid_it.min(),
                                                                  resid_it.max(), 0))
                        ax2.set_title(f'{np.round(tmax_it,2)} yrs', fontsize=fontsize)
                        #         ax2.set_extent(extent_)

                        # GP regression
                        ax3.coastlines(color='k')
                        pc = da_priorplusgpr[i].plot(ax=ax3,
                                                     transform=proj,
                                                     norm=MidpointNormalize(vmin, vmax, 0),
                                                     cmap=cmap,
                                                     extend='both',
                                                     add_colorbar=False)
                        scat = ax3.scatter(lon_it,
                                           lat_it,
                                           s=80,
                                           c=rsl,
                                           edgecolor='k',
                                           cmap=cmap,
                                           norm=MidpointNormalize(vmin, vmax, 0))
                        cbar = fig.colorbar(pc,
                                            ax=ax3,
                                            shrink=.3,
                                            label='RSL (m)',
                                            extend='both')
                        ax3.set_title(f'{np.round(tmax_it,2)} yrs', fontsize=fontsize)
                        #         ax3.set_extent(extent_)

                        #GP regression standard deviation
                        ax4.coastlines(color='k')
                        pc = (2 * np.sqrt(da_varp[i])).plot(
                            ax=ax4,
                            transform=proj,
                            vmin=vmin_std,
                            vmax=vmax_std * 2,
                            cmap='Reds',
                            extend='both',
                            add_colorbar=False,
                        )
                        scat = ax4.scatter(lon_it,
                                           lat_it,
                                           s=80,
                                           c=2 * np.sqrt(var),
                                           vmin=vmin_std,
                                           vmax=vmax_std * 2,
                                           cmap='Reds',
                                           edgecolor='k',
                                           transform=proj)
                        cbar = fig.colorbar(pc,
                                            ax=ax4,
                                            shrink=.3,
                                            extend='both',
                                            label='RSL (m) (2 $\sigma$)')
                        ax4.set_title(f'{np.round(tmax_it,2)} yrs', fontsize=fontsize)
                #         ax4.set_extent(extent_)

                ########## ----- Save figures -------- #######################
                    fig.savefig(dirName + f'{path_gen}_{age}_3D_fig', transparent=True)

                ##################	CHOOSE LOCS W/NUF SAMPS #######################
                ##################  --------------------	 ######################


                def locs_with_enoughsamples(df_place, place, number):
                    """make new dataframe, labeled, of sites with [> number] measurements"""
                    df_lots = df_place.groupby(['lat',
                                                'lon']).filter(lambda x: len(x) > number)

                    df_locs = []
                    for i, group in enumerate(df_lots.groupby(['lat', 'lon'])):
                        singleloc = group[1].copy()
                        singleloc['location'] = place
                        singleloc['locnum'] = place + '_site' + str(
                            i)  # + singleloc.reset_index().index.astype('str')
                        df_locs.append(singleloc)
                    df_locs = pd.concat(df_locs)

                    return df_locs


                number = 6
                df_nufsamps = locs_with_enoughsamples(df_place, place, number)
                len(df_nufsamps.locnum.unique())

                ##################	PLOT LOCS W/NUF SAMPS   #######################
                ##################  --------------------	 ######################


                def slice_dataarray(da):
                    return da.sel(lat=site[1].lat.unique(),
                                  lon=site[1].lon.unique(),
                                  method='nearest')


                fig, ax = plt.subplots(1, len(df_nufsamps.locnum.unique()), figsize=(18, 4))
                ax = ax.ravel()
                colors = ['darkgreen', 'darkblue', 'darkred']
                fontsize = 18

                for i, site in enumerate(df_nufsamps.groupby('locnum')):

                    #slice data for each site
                    prior_it = slice_dataarray(da_giapriorinterp)
                    priorvar_it = slice_dataarray(da_giapriorinterpstd)
                    top_prior = prior_it + priorvar_it * 2
                    bottom_prior = prior_it - priorvar_it * 2

                    var_it = slice_dataarray(np.sqrt(da_varp))
                    post_it = slice_dataarray(da_priorplusgpr)
                    top = post_it + var_it * 2
                    bottom = post_it - var_it * 2

                    site_err = 2 * (site[1].rsl_er_max)

                    ax[i].scatter(site[1].age, site[1].rsl, c=colors[0], label='"true" RSL')
                    ax[i].errorbar(
                        site[1].age,
                        site[1].rsl,
                        site_err,
                        c=colors[0],
                        fmt='none',
                        capsize=1,
                        lw=1,
                    )

                    prior_it.plot(ax=ax[i], c=colors[2], label='Prior $\pm 2 \sigma$')
                    ax[i].fill_between(prior_it.age,
                                       bottom_prior.squeeze(),
                                       top_prior.squeeze(),
                                       color=colors[2],
                                       alpha=0.3)

                    post_it.plot(ax=ax[i], c=colors[1], label='Posterior $\pm 2 \sigma$')
                    ax[i].fill_between(post_it.age,
                                       bottom.squeeze(),
                                       top.squeeze(),
                                       color=colors[1],
                                       alpha=0.3)
                    #     ax[i].set_title(f'{site[0]} RSL', fontsize=fontsize)
                    ax[i].set_title('')

                    ax[i].legend(loc='lower left')

                fig.savefig(dirName + f'{ages[0]}to{ages[-1]}_{place}_realdata_fig_1D',
                            transparent=True)

                #plot locations of data
                fig, ax = plt.subplots(1,
                                       len(df_nufsamps.locnum.unique()),
                                       figsize=(18, 4),
                                       subplot_kw=dict(projection=projection))
                ax = ax.ravel()

                da_zeros = xr.zeros_like(da_zp)

                for i, site in enumerate(df_nufsamps.groupby('locnum')):
                    ax[i].coastlines(color='k')
                    ax[i].plot(site[1].lon.unique(),
                               site[1].lat.unique(),
                               c=colors[0],
                               ms=7,
                               marker='o',
                               transform=proj)
                    ax[i].plot(site[1].lon.unique(),
                               site[1].lat.unique(),
                               c=colors[0],
                               ms=25,
                               marker='o',
                               transform=proj,
                               mfc="None",
                               mec='red',
                               mew=4)
                    da_zeros[0].plot(ax=ax[i], cmap='Greys', add_colorbar=False)
                    ax[i].set_title(site[0], fontsize=fontsize)

                fig.savefig(dirName + f'{path_gen}_1Dlocs_fig', transparent=True)

                #################   DECOMPOSE GPR INTO KERNELS ####################
                ##################  --------------------	 ######################

                if decomp == 'true':

                    def predict_decomp_f(m,
                                         custom_kernel,
                                         predict_at: tf.Tensor,
                                         full_cov: bool = False,
                                         full_output_cov: bool = False,
                                         var=None):
                        """Decompose GP into individual kernels."""

                        x_data, y_data = m.data
                        err = y_data - m.mean_function(x_data)
                        kmm = m.kernel(x_data)
                        knn = custom_kernel(predict_at, full=full_cov)
                        kmn = custom_kernel(x_data, predict_at)
                        num_data = x_data.shape[0]
                        s = tf.linalg.diag(tf.convert_to_tensor(var))  # added diagonal variance
                        conditional = gpf.conditionals.base_conditional
                        f_mean_zero, f_var = conditional(
                            kmn, kmm + s, knn, err, full_cov=full_cov,
                            white=False)  # [N, P], [N, P] or [P, N, N]
                        f_mean = np.array(f_mean_zero + m.mean_function(predict_at))
                        f_var = np.array(f_var)
                        return f_mean, f_var


                    def reshape_decomp(k, var=None):
                        A, var = predict_decomp_f(m, k, xyt, var=var)
                        A = A.reshape(nout, nout, len(ages))
                        var = var.reshape(nout, nout, len(ages))
                        return A, var


                    def make_dataarray(da):
                        coords = [lon, lat, ages]
                        dims = ['lon', 'lat', 'age']
                        return xr.DataArray(da, coords=coords,
                                            dims=dims).transpose('age', 'lat', 'lon')


                    A1, var1 = reshape_decomp(k1,
                                              var=df_place.rsl_er_max.ravel()**2 +
                                              df_place.rsl_giaprior_std.ravel()**2)  #gia spatial
                    A2, var2 = reshape_decomp(k2,
                                              var=df_place.rsl_er_max.ravel()**2 +
                                              df_place.rsl_giaprior_std.ravel()**2)  #gia temporal
                    A3, var3 = reshape_decomp(
                        k3,
                        var=df_place.rsl_er_max.ravel()**2 +
                        df_place.rsl_giaprior_std.ravel()**2)  #readvance spatial
                    A4, var4 = reshape_decomp(
                        k4,
                        var=df_place.rsl_er_max.ravel()**2 +
                        df_place.rsl_giaprior_std.ravel()**2)  #readvance temporal
                    A5, var5 = reshape_decomp(
                        k5,
                        var=df_place.rsl_er_max.ravel()**2 +
                        df_place.rsl_giaprior_std.ravel()**2)  #readvance spatial

                    da_A1 = make_dataarray(A1)
                    da_var1 = make_dataarray(var1)

                    da_A2 = make_dataarray(A2)
                    da_var2 = make_dataarray(var2)

                    da_A3 = make_dataarray(A3)
                    da_var3 = make_dataarray(var3)

                    da_A4 = make_dataarray(A4)
                    da_var4 = make_dataarray(var4)

                    da_A5 = make_dataarray(A5)
                    da_var5 = make_dataarray(var5)

                    #################   PLOT DECOMPOSED KERNELS    ####################
                    ##################  --------------------	   ####################

                    fig, ax = plt.subplots(1, 6, figsize=(24, 4))
                    ax = ax.ravel()
                    da_A1[0, :, :].plot(ax=ax[0], cmap='RdBu_r')

                    da_A2[0, :, :].plot(ax=ax[1], cmap='RdBu_r')

                    da_A3[0, :, :].plot(ax=ax[2], cmap='RdBu_r')

                    da_A4[:, 0, 0].plot(ax=ax[3])

                    da_A5[:, 0, 0].plot(ax=ax[4])

                    fig.savefig(dirName + f'{path_gen}_decompkernels', transparent=True)
                else:
                    pass

            else:
                pass

        #store log likelihood in dataframe
        df_out = pd.DataFrame({'modelrun': modrunlist, 
                             'log_marginal_likelihood': loglikelist})


        writepath = f'output/{path_gen}_loglikelihood'
        df_out.to_csv(writepath, index=False)
        df_likes = pd.read_csv(writepath)

        # make heatmap for upper vs. lower mantle viscosities at one lithosphere thickness

        if ice_model =='glac1d_':
            df_likes['um'] = [key.split('_')[2][3:] for key in df_likes.modelrun]
            df_likes['lm'] = [key.split('_')[3][2:] for key in df_likes.modelrun]
            df_likes['lith'] = [key.split('_')[1][1:3] for key in df_likes.modelrun]
            df_likes['icemodel'] = [key.split('_')[0] for key in df_likes.modelrun]
        elif ice_model == 'd6g_h6g_':
            df_likes = df_likes.drop([36])
            df_likes['um'] = [key.split('_')[3][3:] for key in df_likes.modelrun]
            df_likes['lm'] = [key.split('_')[4][2:] for key in df_likes.modelrun]
            df_likes['lith'] = [key.split('_')[2][1:3] for key in df_likes.modelrun]
            df_likes['icemodel'] = [key.split('_l')[0] for key in df_likes.modelrun]

        df_likes.lm = df_likes.lm.astype(float)
        df_likes.um = df_likes.um.astype(float)
        heatmap = df_likes.pivot_table(index='um', columns='lm', values='log_marginal_likelihood')


        fig, ax = plt.subplots(1, 1, figsize=(6, 6))
        sns.heatmap(heatmap,  cmap='coolwarm', ax=ax,  cbar_kws={'label': 'negative log likelihood'})
        ax.set_title(f'{place} {ages[0]} - {ages[-1]} yrs \n {ice_model} : {df_likes.lith[0]} km lithosphere'); # (havsine)

        fig.savefig(dirName + f'{path_gen}_likelihood_heatmap', transparent=True)   # _havsine
# Out:
# ---------------
# d6g_h6g_l96C_ump2_lm7 run number 0
# number of datapoints =  (125, 8)
# model built, time= 0.017472028732299805
# model minimized, time= 1.1241209506988525
# time elapsed =  1.631284236907959
# negative log marginal likelihood = 34.22449617071506
# ---------------
# d6g_h6g_l96C_ump4_lm15 run number 1
# number of datapoints =  (125, 8)
# model built, time= 0.017340898513793945
# model minimized, time= 0.9916877746582031
# time elapsed =  1.4996528625488281
# negative log marginal likelihood = 34.03280167971832
# ---------------
# d6g_h6g_l96C_ump5_lm20 run number 2
# number of datapoints =  (125, 8)
# model built, time= 0.020982027053833008
# model minimized, time= 1.061061143875122
# time elapsed =  1.5814509391784668
# negative log marginal likelihood = 33.53896862230485
# ---------------
# d6g_h6g_l96C_ump5_lm30 run number 3
# number of datapoints =  (125, 8)
# model built, time= 0.017604827880859375
# model minimized, time= 1.016615867614746
# time elapsed =  1.5405898094177246
# negative log marginal likelihood = 33.518306790082704
# ---------------
# d6g_h6g_l96C_ump4_lm9 run number 4
# number of datapoints =  (125, 8)
# model built, time= 0.018880605697631836
# model minimized, time= 1.2447669506072998
# time elapsed =  1.781139850616455
# negative log marginal likelihood = 33.22169991392215
# ---------------
# d6g_h6g_l96C_ump5_lm5 run number 5
# number of datapoints =  (125, 8)
# model built, time= 0.018761873245239258
# model minimized, time= 1.2747199535369873
# time elapsed =  1.8121438026428223
# negative log marginal likelihood = 33.013563326269676
# ---------------
# d6g_h6g_l96C_ump2_lm3 run number 6
# number of datapoints =  (125, 8)
# model built, time= 0.02123427391052246
# model minimized, time= 1.2671589851379395
# time elapsed =  1.8792262077331543
# negative log marginal likelihood = 34.0740487868385
# ---------------
# d6g_h6g_l96C_ump5_lm10 run number 7
# number of datapoints =  (125, 8)
# model built, time= 0.02022099494934082
# model minimized, time= 1.1397290229797363
# time elapsed =  1.7343549728393555
# negative log marginal likelihood = 33.56902952752084
# ---------------
# d6g_h6g_l96C_ump4_lm40 run number 8
# number of datapoints =  (125, 8)
# model built, time= 0.0202181339263916
# model minimized, time= 1.1013050079345703
# time elapsed =  1.594520092010498
# negative log marginal likelihood = 34.26994218540868
# ---------------
# d6g_h6g_l96C_ump4_lm50 run number 9
# number of datapoints =  (125, 8)
# model built, time= 0.020776033401489258
# model minimized, time= 1.173797845840454
# time elapsed =  1.6972630023956299
# negative log marginal likelihood = 34.269321195152855
# ---------------
# d6g_h6g_l96C_ump5_lm40 run number 10
# number of datapoints =  (125, 8)
# model built, time= 0.021767377853393555
# model minimized, time= 1.2596092224121094
# time elapsed =  1.7068243026733398
# negative log marginal likelihood = 34.25511592159333
# ---------------
# d6g_h6g_l96C_ump4_lm10 run number 11
# number of datapoints =  (125, 8)
# model built, time= 0.019651174545288086
# model minimized, time= 0.9604322910308838
# time elapsed =  1.4529132843017578
# negative log marginal likelihood = 34.83502870615597
# ---------------
# d6g_h6g_l96C_ump5_lm50 run number 12
# number of datapoints =  (125, 8)
# model built, time= 0.019312143325805664
# model minimized, time= 0.8113992214202881
# time elapsed =  1.2940831184387207
# negative log marginal likelihood = 35.984850550978294
# ---------------
# d6g_h6g_l96C_ump4_lm20 run number 13
# number of datapoints =  (125, 8)
# model built, time= 0.018723011016845703
# model minimized, time= 1.2306957244873047
# time elapsed =  1.7298028469085693
# negative log marginal likelihood = 33.23096406347699
# ---------------
# d6g_h6g_l96C_ump5_lm15 run number 14
# number of datapoints =  (125, 8)
# model built, time= 0.019534826278686523
# model minimized, time= 1.036376953125
# time elapsed =  1.5661070346832275
# negative log marginal likelihood = 32.56068125409243
# ---------------
# d6g_h6g_l96C_ump4_lm30 run number 15
# number of datapoints =  (125, 8)
# model built, time= 0.019713640213012695
# model minimized, time= 1.1464998722076416
# time elapsed =  1.6943297386169434
# negative log marginal likelihood = 33.29400635820876
# ---------------
# d6g_h6g_l96C_ump4_lm8 run number 16
# number of datapoints =  (125, 8)
# model built, time= 0.021188020706176758
# model minimized, time= 1.3326449394226074
# time elapsed =  1.9665660858154297
# negative log marginal likelihood = 32.651644272723146
# ---------------
# d6g_h6g_l96C_ump4_lm3 run number 17
# number of datapoints =  (125, 8)
# model built, time= 0.01867079734802246
# model minimized, time= 1.04225492477417
# time elapsed =  1.7028579711914062
# negative log marginal likelihood = 33.864800260350876
# ---------------
# d6g_h6g_l96C_ump3_lm5 run number 18
# number of datapoints =  (125, 8)
# model built, time= 0.0184781551361084
# model minimized, time= 0.9251949787139893
# time elapsed =  1.4421160221099854
# negative log marginal likelihood = 32.29158392957146
# ---------------
# d6g_h6g_l96C_ump2_lm9 run number 19
# number of datapoints =  (125, 8)
# model built, time= 0.017235279083251953
# model minimized, time= 0.9012181758880615
# time elapsed =  1.4639601707458496
# negative log marginal likelihood = 33.69250246666567
# ---------------
# d6g_h6g_l96C_ump4_lm7 run number 20
# number of datapoints =  (125, 8)
# model built, time= 0.01949596405029297
# model minimized, time= 1.7183470726013184
# time elapsed =  2.224017858505249
# negative log marginal likelihood = 33.685899729220324
# ---------------
# d6g_h6g_l96C_ump2_lm8 run number 21
# number of datapoints =  (125, 8)
# model built, time= 0.018400907516479492
# model minimized, time= 1.0748770236968994
# time elapsed =  1.6191980838775635
# negative log marginal likelihood = 33.41298574820422
# ---------------
# d6g_h6g_l96C_ump3_lm50 run number 22
# number of datapoints =  (125, 8)
# model built, time= 0.017358779907226562
# model minimized, time= 1.133753776550293
# time elapsed =  1.6396510601043701
# negative log marginal likelihood = 33.38987629006546
# ---------------
# d6g_h6g_l96C_ump2_lm10 run number 23
# number of datapoints =  (125, 8)
# model built, time= 0.019710063934326172
# model minimized, time= 0.9905178546905518
# time elapsed =  1.493307113647461
# negative log marginal likelihood = 33.18279289114551
# ---------------
# d6g_h6g_l96C_ump3_lm3 run number 24
# number of datapoints =  (125, 8)
# model built, time= 0.018642902374267578
# model minimized, time= 0.9882190227508545
# time elapsed =  1.5073397159576416
# negative log marginal likelihood = 33.392167459076305
# ---------------
# d6g_h6g_l96C_ump3_lm40 run number 25
# number of datapoints =  (125, 8)
# model built, time= 0.01985001564025879
# model minimized, time= 1.0212743282318115
# time elapsed =  1.5544471740722656
# negative log marginal likelihood = 32.20524339833344
# ---------------
# d6g_h6g_l96C_ump4_lm5 run number 26
# number of datapoints =  (125, 8)
# model built, time= 0.01788496971130371
# model minimized, time= 0.9052009582519531
# time elapsed =  1.4253580570220947
# negative log marginal likelihood = 33.951554192737845
# ---------------
# d6g_h6g_l96C_ump2_lm30 run number 27
# number of datapoints =  (125, 8)
# model built, time= 0.017342090606689453
# model minimized, time= 0.9899740219116211
# time elapsed =  1.5247838497161865
# negative log marginal likelihood = 31.764539683160194
# ---------------
# d6g_h6g_l96C_ump5_lm9 run number 28
# number of datapoints =  (125, 8)
# model built, time= 0.019033193588256836
# model minimized, time= 1.1086480617523193
# time elapsed =  1.6226890087127686
# negative log marginal likelihood = 33.130606306224834
# ---------------
# d6g_h6g_l96C_ump2_lm20 run number 29
# number of datapoints =  (125, 8)
# model built, time= 0.02156376838684082
# model minimized, time= 1.2602858543395996
# time elapsed =  1.764909029006958
# negative log marginal likelihood = 31.59380206867563
# ---------------
# d6g_h6g_l96C_ump3_lm15 run number 30
# number of datapoints =  (125, 8)
# model built, time= 0.019287824630737305
# model minimized, time= 0.9613277912139893
# time elapsed =  1.5043878555297852
# negative log marginal likelihood = 34.67433176775394
# ---------------
# d6g_h6g_l96C_ump3_lm7 run number 31
# number of datapoints =  (125, 8)
# model built, time= 0.019215106964111328
# model minimized, time= 1.0967321395874023
# time elapsed =  1.6173510551452637
# negative log marginal likelihood = 34.66133294801932
# ---------------
# d6g_h6g_l96C_ump3_lm30 run number 32
# number of datapoints =  (125, 8)
# model built, time= 0.018941879272460938
# model minimized, time= 1.1941797733306885
# time elapsed =  1.7296278476715088
# negative log marginal likelihood = 33.915134134782775
# ---------------
# d6g_h6g_l96C_ump5_lm8 run number 33
# number of datapoints =  (125, 8)
# model built, time= 0.018314123153686523
# model minimized, time= 1.267289161682129
# time elapsed =  1.7756850719451904
# negative log marginal likelihood = 32.8069781287502
# ---------------
# d6g_h6g_l96C_ump2_lm15 run number 34
# number of datapoints =  (125, 8)
# model built, time= 0.01771378517150879
# model minimized, time= 1.032498836517334
# time elapsed =  1.527115821838379
# negative log marginal likelihood = 32.485950729696725
# ---------------
# d6g_h6g_l96C_ump3_lm20 run number 35
# number of datapoints =  (125, 8)
# model built, time= 0.017402172088623047
# model minimized, time= 1.096479892730713
# time elapsed =  1.6103451251983643
# negative log marginal likelihood = 32.66466237480908
# ---------------
# d6g_h6g_l96C_ump2_lm50 run number 36
# number of datapoints =  (125, 8)
# model built, time= 0.018062114715576172
# model minimized, time= 0.9500820636749268
# time elapsed =  1.4838709831237793
# negative log marginal likelihood = 32.419434164297655
# ---------------
# d6g_h6g_l96C_ump2_lm40 run number 37
# number of datapoints =  (125, 8)
# model built, time= 0.017976045608520508
# model minimized, time= 1.0622971057891846
# time elapsed =  1.5706138610839844
# negative log marginal likelihood = 32.329228733829524
# ---------------
# d6g_h6g_l96C_ump3_lm10 run number 38
# number of datapoints =  (125, 8)
# model built, time= 0.01759791374206543
# model minimized, time= 0.9309849739074707
# time elapsed =  1.430696964263916
# negative log marginal likelihood = 31.57966863242126
# ---------------
# d6g_h6g_l96C_ump5_lm7 run number 39
# number of datapoints =  (125, 8)
# model built, time= 0.0173797607421875
# model minimized, time= 1.0224740505218506
# time elapsed =  1.5388469696044922
# negative log marginal likelihood = 33.17872132034769
# ---------------
# d6g_h6g_l96C_ump3_lm9 run number 40
# number of datapoints =  (125, 8)
# model built, time= 0.017401933670043945
# model minimized, time= 0.9557449817657471
# time elapsed =  1.4658818244934082
# negative log marginal likelihood = 32.09368421664897
# ---------------
# d6g_h6g_l96C_ump2_lm5 run number 41
# number of datapoints =  (125, 8)
# model built, time= 0.01712799072265625
# model minimized, time= 0.9419870376586914
# time elapsed =  1.4491760730743408
# negative log marginal likelihood = 34.566401955284064
# ---------------
# d6g_h6g_l96C_ump5_lm3 run number 42
# number of datapoints =  (125, 8)
# model built, time= 0.017815113067626953
# model minimized, time= 0.9999899864196777
# time elapsed =  1.5074732303619385
# negative log marginal likelihood = 33.34998968051559
# ---------------
# d6g_h6g_l96C_ump3_lm8 run number 43
# number of datapoints =  (125, 8)
# model built, time= 0.017620086669921875
# model minimized, time= 1.0293278694152832
# time elapsed =  1.5224368572235107
# negative log marginal likelihood = 32.83346378178595
# ---------------
# d6g_h6g_l71C_ump4_lm50 run number 0
# number of datapoints =  (125, 8)
# model built, time= 0.018661975860595703
# model minimized, time= 0.9928579330444336
# time elapsed =  1.4384751319885254
# negative log marginal likelihood = 33.61630323654077
# ---------------
# d6g_h6g_l71C_ump4_lm40 run number 1
# number of datapoints =  (125, 8)
# model built, time= 0.01767897605895996
# model minimized, time= 0.9658939838409424
# time elapsed =  1.4121592044830322
# negative log marginal likelihood = 33.42621215772448
# ---------------
# d6g_h6g_l71C_ump5_lm10 run number 2
# number of datapoints =  (125, 8)
# model built, time= 0.01793193817138672
# model minimized, time= 0.9124629497528076
# time elapsed =  1.4255988597869873
# negative log marginal likelihood = 33.038787087052725
# ---------------
# d6g_h6g_l71C_ump5_lm30 run number 3
# number of datapoints =  (125, 8)
# model built, time= 0.019555091857910156
# model minimized, time= 1.0171267986297607
# time elapsed =  1.5462541580200195
# negative log marginal likelihood = 32.66690768008992
# ---------------
# d6g_h6g_l71C_ump2_lm8 run number 4
# number of datapoints =  (125, 8)
# model built, time= 0.01961493492126465
# model minimized, time= 1.0716590881347656
# time elapsed =  1.5880789756774902
# negative log marginal likelihood = 33.438950559052785
# ---------------
# d6g_h6g_l71C_ump4_lm15 run number 5
# number of datapoints =  (125, 8)
# model built, time= 0.019381046295166016
# model minimized, time= 1.0402100086212158
# time elapsed =  1.5380370616912842
# negative log marginal likelihood = 34.79837059177305
# ---------------
# d6g_h6g_l71C_ump5_lm20 run number 6
# number of datapoints =  (125, 8)
# model built, time= 0.01921820640563965
# model minimized, time= 1.2756690979003906
# time elapsed =  1.7529520988464355
# negative log marginal likelihood = 33.44268190479889
# ---------------
# d6g_h6g_l71C_ump2_lm9 run number 7
# number of datapoints =  (125, 8)
# model built, time= 0.017547130584716797
# model minimized, time= 1.053563117980957
# time elapsed =  1.5270841121673584
# negative log marginal likelihood = 32.70371269665334
# ---------------
# d6g_h6g_l71C_ump4_lm30 run number 8
# number of datapoints =  (125, 8)
# model built, time= 0.01775217056274414
# model minimized, time= 0.8885660171508789
# time elapsed =  1.3841049671173096
# negative log marginal likelihood = 33.61751727746763
# ---------------
# d6g_h6g_l71C_ump4_lm20 run number 9
# number of datapoints =  (125, 8)
# model built, time= 0.019336938858032227
# model minimized, time= 1.1092281341552734
# time elapsed =  1.6141350269317627
# negative log marginal likelihood = 33.64350161813786
# ---------------
# d6g_h6g_l71C_ump5_lm15 run number 10
# number of datapoints =  (125, 8)
# model built, time= 0.018435001373291016
# model minimized, time= 0.8968839645385742
# time elapsed =  1.4136149883270264
# negative log marginal likelihood = 33.62368886243391
# ---------------
# d6g_h6g_l71C_ump4_lm7 run number 11
# number of datapoints =  (125, 8)
# model built, time= 0.021138906478881836
# model minimized, time= 1.0797181129455566
# time elapsed =  1.6075870990753174
# negative log marginal likelihood = 33.05530805286715
# ---------------
# d6g_h6g_l71C_ump5_lm50 run number 12
# number of datapoints =  (125, 8)
# model built, time= 0.019711017608642578
# model minimized, time= 1.0566680431365967
# time elapsed =  1.5670628547668457
# negative log marginal likelihood = 32.84663639886794
# ---------------
# d6g_h6g_l71C_ump3_lm5 run number 13
# number of datapoints =  (125, 8)
# model built, time= 0.019977092742919922
# model minimized, time= 0.9466471672058105
# time elapsed =  1.5079329013824463
# negative log marginal likelihood = 32.67151801299936
# ---------------
# d6g_h6g_l71C_ump4_lm10 run number 14
# number of datapoints =  (125, 8)
# model built, time= 0.020712852478027344
# model minimized, time= 0.9331479072570801
# time elapsed =  1.4807119369506836
# negative log marginal likelihood = 32.23328409254091
# ---------------
# d6g_h6g_l71C_ump5_lm40 run number 15
# number of datapoints =  (125, 8)
# model built, time= 0.021783113479614258
# model minimized, time= 1.012641191482544
# time elapsed =  1.545152187347412
# negative log marginal likelihood = 32.39171248146175
# ---------------
# d6g_h6g_l71C_ump4_lm3 run number 16
# number of datapoints =  (125, 8)
# model built, time= 0.022526025772094727
# model minimized, time= 1.0814340114593506
# time elapsed =  1.5891931056976318
# negative log marginal likelihood = 32.16244357808378
# ---------------
# d6g_h6g_l71C_ump4_lm8 run number 17
# number of datapoints =  (125, 8)
# model built, time= 0.018363237380981445
# model minimized, time= 0.9172050952911377
# time elapsed =  1.4207379817962646
# negative log marginal likelihood = 32.841844694961594
# ---------------
# d6g_h6g_l71C_ump2_lm3 run number 18
# number of datapoints =  (125, 8)
# model built, time= 0.017210960388183594
# model minimized, time= 0.9728190898895264
# time elapsed =  1.4767711162567139
# negative log marginal likelihood = 31.833562566937616
# ---------------
# d6g_h6g_l71C_ump5_lm5 run number 19
# number of datapoints =  (125, 8)
# model built, time= 0.017960071563720703
# model minimized, time= 0.9208378791809082
# time elapsed =  1.4270050525665283
# negative log marginal likelihood = 32.833507588499074
# ---------------
# d6g_h6g_l71C_ump2_lm7 run number 20
# number of datapoints =  (125, 8)
# model built, time= 0.017944812774658203
# model minimized, time= 0.8837509155273438
# time elapsed =  1.3945069313049316
# negative log marginal likelihood = 34.17009748416139
# ---------------
# d6g_h6g_l71C_ump4_lm9 run number 21
# number of datapoints =  (125, 8)
# model built, time= 0.023356914520263672
# model minimized, time= 0.9566957950592041
# time elapsed =  1.4797089099884033
# negative log marginal likelihood = 33.45785144135314
# ---------------
# d6g_h6g_l71C_ump2_lm20 run number 22
# number of datapoints =  (125, 8)
# model built, time= 0.019396066665649414
# model minimized, time= 1.077685832977295
# time elapsed =  1.5838890075683594
# negative log marginal likelihood = 32.81589999582849
# ---------------
# d6g_h6g_l71C_ump3_lm15 run number 23
# number of datapoints =  (125, 8)
# model built, time= 0.026027917861938477
# model minimized, time= 1.0529210567474365
# time elapsed =  1.5464119911193848
# negative log marginal likelihood = 32.62017374658092
# ---------------
# d6g_h6g_l71C_ump2_lm30 run number 24
# number of datapoints =  (125, 8)
# model built, time= 0.0179288387298584
# model minimized, time= 0.9234027862548828
# time elapsed =  1.4299538135528564
# negative log marginal likelihood = 32.223856430444116
# ---------------
# d6g_h6g_l71C_ump3_lm8 run number 25
# number of datapoints =  (125, 8)
# model built, time= 0.01718306541442871
# model minimized, time= 1.0910348892211914
# time elapsed =  1.5878429412841797
# negative log marginal likelihood = 32.6522122995903
# ---------------
# d6g_h6g_l71C_ump3_lm40 run number 26
# number of datapoints =  (125, 8)
# model built, time= 0.01743602752685547
# model minimized, time= 0.948361873626709
# time elapsed =  1.4539330005645752
# negative log marginal likelihood = 32.99762561107873
# ---------------
# d6g_h6g_l71C_ump2_lm10 run number 27
# number of datapoints =  (125, 8)
# model built, time= 0.018922090530395508
# model minimized, time= 0.8588612079620361
# time elapsed =  1.363239049911499
# negative log marginal likelihood = 33.22786315197119
# ---------------
# d6g_h6g_l71C_ump3_lm50 run number 28
# number of datapoints =  (125, 8)
# model built, time= 0.017644166946411133
# model minimized, time= 0.9599711894989014
# time elapsed =  1.452341079711914
# negative log marginal likelihood = 32.57270025270124
# ---------------
# d6g_h6g_l71C_ump5_lm3 run number 29
# number of datapoints =  (125, 8)
# model built, time= 0.018824338912963867
# model minimized, time= 1.0590572357177734
# time elapsed =  1.5647830963134766
# negative log marginal likelihood = 31.739035340254773
# ---------------
# d6g_h6g_l71C_ump2_lm5 run number 30
# number of datapoints =  (125, 8)
# model built, time= 0.018730878829956055
# model minimized, time= 1.1633121967315674
# time elapsed =  1.6704919338226318
# negative log marginal likelihood = 32.579336973991545
# ---------------
# d6g_h6g_l71C_ump3_lm10 run number 31
# number of datapoints =  (125, 8)
# model built, time= 0.02377605438232422
# model minimized, time= 1.0526878833770752
# time elapsed =  1.5476040840148926
# negative log marginal likelihood = 32.61079906056085
# ---------------
# d6g_h6g_l71C_ump2_lm40 run number 32
# number of datapoints =  (125, 8)
# model built, time= 0.01724982261657715
# model minimized, time= 0.9786229133605957
# time elapsed =  1.4850099086761475
# negative log marginal likelihood = 32.837688360320556
# ---------------
# d6g_h6g_l71C_ump2_lm50 run number 33
# number of datapoints =  (125, 8)
# model built, time= 0.019057035446166992
# model minimized, time= 0.9883561134338379
# time elapsed =  1.51556396484375
# negative log marginal likelihood = 32.84351263922649
# ---------------
# d6g_h6g_l71C_ump5_lm7 run number 34
# number of datapoints =  (125, 8)
# model built, time= 0.017457962036132812
# model minimized, time= 1.0843868255615234
# time elapsed =  1.5728931427001953
# negative log marginal likelihood = 32.080070359394554
# ---------------
# d6g_h6g_l71C_ump2_lm15 run number 35
# number of datapoints =  (125, 8)
# model built, time= 0.017941951751708984
# model minimized, time= 1.017409086227417
# time elapsed =  1.517016887664795
# negative log marginal likelihood = 31.83982777693133
# ---------------
# d6g_h6g_l71C_ump3_lm20 run number 36
# number of datapoints =  (125, 8)
# model built, time= 0.018646955490112305
# model minimized, time= 0.9971568584442139
# time elapsed =  1.4900989532470703
# negative log marginal likelihood = 31.64743441768674
# ---------------
# d6g_h6g_l71C_ump3_lm30 run number 37
# number of datapoints =  (125, 8)
# model built, time= 0.017596006393432617
# model minimized, time= 0.9810709953308105
# time elapsed =  1.484055995941162
# negative log marginal likelihood = 31.49412221919144
# ---------------
# d6g_h6g_l71C_ump3_lm9 run number 38
# number of datapoints =  (125, 8)
# model built, time= 0.01841425895690918
# model minimized, time= 1.0002162456512451
# time elapsed =  1.5104310512542725
# negative log marginal likelihood = 31.842725306086862
# ---------------
# d6g_h6g_l71C_ump5_lm8 run number 39
# number of datapoints =  (125, 8)
# model built, time= 0.018276214599609375
# model minimized, time= 0.9138329029083252
# time elapsed =  1.412654161453247
# negative log marginal likelihood = 32.56177852424565
# ---------------
# d6g_h6g_l71C_ump5_lm9 run number 40
# number of datapoints =  (125, 8)
# model built, time= 0.01748490333557129
# model minimized, time= 0.931663990020752
# time elapsed =  1.4333839416503906
# negative log marginal likelihood = 33.02450976049755
# ---------------
# d6g_h6g_l71C_ump3_lm7 run number 41
# number of datapoints =  (125, 8)
# model built, time= 0.018314838409423828
# model minimized, time= 0.9612278938293457
# time elapsed =  1.455826759338379
# negative log marginal likelihood = 32.813716477322686
# ---------------
# d6g_h6g_l71C_ump4_lm5 run number 42
# number of datapoints =  (125, 8)
# model built, time= 0.019271135330200195
# model minimized, time= 1.0669560432434082
# time elapsed =  1.489358901977539
# negative log marginal likelihood = 34.06982242475203
# ---------------
# d6g_h6g_l71C_ump3_lm3 run number 43
# number of datapoints =  (125, 8)
# model built, time= 0.022462844848632812
# model minimized, time= 1.0547938346862793
# time elapsed =  1.5449309349060059
# negative log marginal likelihood = 34.26904016703169
# ---------------
# glac1d_l96C_ump4_lm50 run number 0
# number of datapoints =  (125, 8)
# model built, time= 0.02283310890197754
# model minimized, time= 1.2056260108947754
# time elapsed =  1.716364860534668
# negative log marginal likelihood = 11.112125939732096
# ---------------
# glac1d_l96C_ump3_lm8 run number 1
# number of datapoints =  (125, 8)
# model built, time= 0.01720595359802246
# model minimized, time= 0.8320541381835938
# time elapsed =  1.3537240028381348
# negative log marginal likelihood = 11.266319419441103
# ---------------
# glac1d_l96C_ump5_lm10 run number 2
# number of datapoints =  (125, 8)
# model built, time= 0.02176189422607422
# model minimized, time= 1.0241291522979736
# time elapsed =  1.5347890853881836
# negative log marginal likelihood = 11.329909490759931
# ---------------
# glac1d_l96C_ump4_lm40 run number 3
# number of datapoints =  (125, 8)
# model built, time= 0.019171953201293945
# model minimized, time= 0.9818217754364014
# time elapsed =  1.4983079433441162
# negative log marginal likelihood = 9.72302080025841
# ---------------
# glac1d_l96C_ump5_lm30 run number 4
# number of datapoints =  (125, 8)
# model built, time= 0.018990755081176758
# model minimized, time= 1.0582127571105957
# time elapsed =  1.5705158710479736
# negative log marginal likelihood = 11.387720385188729
# ---------------
# glac1d_l96C_ump4_lm15 run number 5
# number of datapoints =  (125, 8)
# model built, time= 0.018355131149291992
# model minimized, time= 0.9838240146636963
# time elapsed =  1.4848320484161377
# negative log marginal likelihood = 11.414478682640492
# ---------------
# glac1d_l96C_ump5_lm20 run number 6
# number of datapoints =  (125, 8)
# model built, time= 0.017786026000976562
# model minimized, time= 0.8181548118591309
# time elapsed =  1.2831008434295654
# negative log marginal likelihood = 12.006623950851491
# ---------------
# glac1d_l96C_ump4_lm30 run number 7
# number of datapoints =  (125, 8)
# model built, time= 0.02042388916015625
# model minimized, time= 1.3734877109527588
# time elapsed =  1.8838059902191162
# negative log marginal likelihood = 11.414228587994643
# ---------------
# glac1d_l96C_ump5_lm3 run number 8
# number of datapoints =  (125, 8)
# model built, time= 0.0198211669921875
# model minimized, time= 0.9307289123535156
# time elapsed =  1.4212911128997803
# negative log marginal likelihood = 10.973786844153551
# ---------------
# glac1d_l96C_ump2_lm5 run number 9
# number of datapoints =  (125, 8)
# model built, time= 0.017491817474365234
# model minimized, time= 1.1347038745880127
# time elapsed =  1.6388700008392334
# negative log marginal likelihood = 11.003137465593852
# ---------------
# glac1d_l96C_ump4_lm20 run number 10
# number of datapoints =  (125, 8)
# model built, time= 0.018069982528686523
# model minimized, time= 0.9943649768829346
# time elapsed =  1.473426103591919
# negative log marginal likelihood = 11.074167497012269
# ---------------
# glac1d_l96C_ump5_lm15 run number 11
# number of datapoints =  (125, 8)
# model built, time= 0.017702817916870117
# model minimized, time= 1.0869629383087158
# time elapsed =  1.5668749809265137
# negative log marginal likelihood = 16.67686487581848
# ---------------
# glac1d_l96C_ump3_lm9 run number 12
# number of datapoints =  (125, 8)
# model built, time= 0.017940998077392578
# model minimized, time= 1.0300991535186768
# time elapsed =  1.5724461078643799
# negative log marginal likelihood = 16.93060666591711
# ---------------
# glac1d_l96C_ump5_lm50 run number 13
# number of datapoints =  (125, 8)
# model built, time= 0.0200650691986084
# model minimized, time= 1.0035932064056396
# time elapsed =  1.4566702842712402
# negative log marginal likelihood = 17.188824685178503
# ---------------
# glac1d_l96C_ump5_lm40 run number 14
# number of datapoints =  (125, 8)
# model built, time= 0.018451929092407227
# model minimized, time= 1.0985379219055176
# time elapsed =  1.5441160202026367
# negative log marginal likelihood = 14.344894949310017
# ---------------
# glac1d_l96C_ump4_lm10 run number 15
# number of datapoints =  (125, 8)
# model built, time= 0.017396926879882812
# model minimized, time= 0.8982789516448975
# time elapsed =  1.3810029029846191
# negative log marginal likelihood = 17.444428734640667
# ---------------
# glac1d_l96C_ump5_lm7 run number 16
# number of datapoints =  (125, 8)
# model built, time= 0.018050193786621094
# model minimized, time= 0.9575309753417969
# time elapsed =  1.4252421855926514
# negative log marginal likelihood = 17.2042869858726
# ---------------
# glac1d_l96C_ump5_lm8 run number 17
# number of datapoints =  (125, 8)
# model built, time= 0.017480850219726562
# model minimized, time= 1.0867557525634766
# time elapsed =  1.5829598903656006
# negative log marginal likelihood = 15.911933389898138
# ---------------
# glac1d_l96C_ump3_lm7 run number 18
# number of datapoints =  (125, 8)
# model built, time= 0.017251968383789062
# model minimized, time= 1.0204517841339111
# time elapsed =  1.5031969547271729
# negative log marginal likelihood = 16.973204152015057
# ---------------
# glac1d_l96C_ump5_lm9 run number 19
# number of datapoints =  (125, 8)
# model built, time= 0.018572568893432617
# model minimized, time= 1.301245927810669
# time elapsed =  1.7676308155059814
# negative log marginal likelihood = 16.24565149001596
# ---------------
# glac1d_l96C_ump4_lm5 run number 20
# number of datapoints =  (125, 8)
# model built, time= 0.028889179229736328
# model minimized, time= 1.100926160812378
# time elapsed =  1.6410191059112549
# negative log marginal likelihood = 16.349086425451603
# ---------------
# glac1d_l96C_ump3_lm3 run number 21
# number of datapoints =  (125, 8)
# model built, time= 0.019713163375854492
# model minimized, time= 1.6071271896362305
# time elapsed =  2.119197368621826
# negative log marginal likelihood = 16.413978297634372
# ---------------
# glac1d_l96C_ump2_lm20 run number 22
# number of datapoints =  (125, 8)
# model built, time= 0.017589092254638672
# model minimized, time= 0.8999030590057373
# time elapsed =  1.364698886871338
# negative log marginal likelihood = 22.699117828762553
# ---------------
# glac1d_l96C_ump3_lm15 run number 23
# number of datapoints =  (125, 8)
# model built, time= 0.018217086791992188
# model minimized, time= 1.1816160678863525
# time elapsed =  1.6872878074645996
# negative log marginal likelihood = 22.428519556673365
# ---------------
# glac1d_l96C_ump2_lm30 run number 24
# number of datapoints =  (125, 8)
# model built, time= 0.01741814613342285
# model minimized, time= 1.0634119510650635
# time elapsed =  1.570547342300415
# negative log marginal likelihood = 23.590964550764753
# ---------------
# glac1d_l96C_ump2_lm10 run number 25
# number of datapoints =  (125, 8)
# model built, time= 0.0199887752532959
# model minimized, time= 1.566849946975708
# time elapsed =  2.1130948066711426
# negative log marginal likelihood = 18.98682198993052
# ---------------
# glac1d_l96C_ump3_lm40 run number 26
# number of datapoints =  (125, 8)
# model built, time= 0.018873929977416992
# model minimized, time= 1.1720249652862549
# time elapsed =  1.6931309700012207
# negative log marginal likelihood = 23.14387540772198
# ---------------
# glac1d_l96C_ump3_lm50 run number 27
# number of datapoints =  (125, 8)
# model built, time= 0.017483949661254883
# model minimized, time= 1.0000498294830322
# time elapsed =  1.5229287147521973
# negative log marginal likelihood = 23.7079475060809
# ---------------
# glac1d_l96C_ump2_lm8 run number 28
# number of datapoints =  (125, 8)
# model built, time= 0.022904157638549805
# model minimized, time= 1.3004729747772217
# time elapsed =  1.8013880252838135
# negative log marginal likelihood = 21.45234080689849
# ---------------
# glac1d_l96C_ump4_lm7 run number 29
# number of datapoints =  (125, 8)
# model built, time= 0.02010798454284668
# model minimized, time= 1.2890548706054688
# time elapsed =  1.7996788024902344
# negative log marginal likelihood = 27.00829482755333
# ---------------
# glac1d_l96C_ump2_lm40 run number 30
# number of datapoints =  (125, 8)
# model built, time= 0.019607067108154297
# model minimized, time= 1.2229681015014648
# time elapsed =  1.7234561443328857
# negative log marginal likelihood = 22.226539968246186
# ---------------
# glac1d_l96C_ump3_lm10 run number 31
# number of datapoints =  (125, 8)
# model built, time= 0.019995689392089844
# model minimized, time= 1.2906057834625244
# time elapsed =  1.8178496360778809
# negative log marginal likelihood = 21.830327476851807
# ---------------
# glac1d_l96C_ump2_lm50 run number 32
# number of datapoints =  (125, 8)
# model built, time= 0.019867897033691406
# model minimized, time= 1.1993801593780518
# time elapsed =  1.697962999343872
# negative log marginal likelihood = 22.64640343711929
# ---------------
# glac1d_l96C_ump2_lm9 run number 33
# number of datapoints =  (125, 8)
# model built, time= 0.017524242401123047
# model minimized, time= 0.9099769592285156
# time elapsed =  1.3784942626953125
# negative log marginal likelihood = 32.847443472741446
# ---------------
# glac1d_l96C_ump3_lm5 run number 34
# number of datapoints =  (125, 8)
# model built, time= 0.02009415626525879
# model minimized, time= 1.1006710529327393
# time elapsed =  1.639599084854126
# negative log marginal likelihood = 33.28524368257665
# ---------------
# glac1d_l96C_ump4_lm3 run number 35
# number of datapoints =  (125, 8)
# model built, time= 0.018110990524291992
# model minimized, time= 0.9794919490814209
# time elapsed =  1.466149091720581
# negative log marginal likelihood = 29.820403467711245
# ---------------
# glac1d_l96C_ump2_lm15 run number 36
# number of datapoints =  (125, 8)
# model built, time= 0.017409086227416992
# model minimized, time= 0.8534641265869141
# time elapsed =  1.3605930805206299
# negative log marginal likelihood = 28.34399813288087
# ---------------
# glac1d_l96C_ump3_lm20 run number 37
# number of datapoints =  (125, 8)
# model built, time= 0.019227027893066406
# model minimized, time= 0.9558851718902588
# time elapsed =  1.410356044769287
# negative log marginal likelihood = 28.052378559691817
# ---------------
# glac1d_l96C_ump3_lm30 run number 38
# number of datapoints =  (125, 8)
# model built, time= 0.017590045928955078
# model minimized, time= 0.9669969081878662
# time elapsed =  1.4426250457763672
# negative log marginal likelihood = 28.767986154706108
# ---------------
# glac1d_l96C_ump4_lm8 run number 39
# number of datapoints =  (125, 8)
# model built, time= 0.01851797103881836
# model minimized, time= 0.9007260799407959
# time elapsed =  1.3758010864257812
# negative log marginal likelihood = 27.48069742694183
# ---------------
# glac1d_l96C_ump2_lm3 run number 40
# number of datapoints =  (125, 8)
# model built, time= 0.023786067962646484
# model minimized, time= 1.0692229270935059
# time elapsed =  1.5754539966583252
# negative log marginal likelihood = 27.801644958747588
# ---------------
# glac1d_l96C_ump5_lm5 run number 41
# number of datapoints =  (125, 8)
# model built, time= 0.017775774002075195
# model minimized, time= 0.903134822845459
# time elapsed =  1.408134937286377
# negative log marginal likelihood = 32.93768733352967
# ---------------
# glac1d_l96C_ump4_lm9 run number 42
# number of datapoints =  (125, 8)
# model built, time= 0.02003788948059082
# model minimized, time= 1.0064430236816406
# time elapsed =  1.5062510967254639
# negative log marginal likelihood = 33.1553541022659
# ---------------
# glac1d_l96C_ump2_lm7 run number 43
# number of datapoints =  (125, 8)
# model built, time= 0.019954919815063477
# model minimized, time= 1.0548596382141113
# time elapsed =  1.5681238174438477
# negative log marginal likelihood = 32.60780287192402
# ---------------
# glac1d_l71C_ump3_lm3 run number 0
# number of datapoints =  (125, 8)
# model built, time= 0.02034282684326172
# model minimized, time= 0.9227969646453857
# time elapsed =  1.4395849704742432
# negative log marginal likelihood = 9.580333158736948
# ---------------
# glac1d_l71C_ump4_lm5 run number 1
# number of datapoints =  (125, 8)
# model built, time= 0.018619060516357422
# model minimized, time= 0.857673168182373
# time elapsed =  1.348757266998291
# negative log marginal likelihood = 9.736743534168255
# ---------------
# glac1d_l71C_ump4_lm15 run number 2
# number of datapoints =  (125, 8)
# model built, time= 0.01759195327758789
# model minimized, time= 0.9903688430786133
# time elapsed =  1.498403787612915
# negative log marginal likelihood = 9.762333469349713
# ---------------
# glac1d_l71C_ump5_lm20 run number 3
# number of datapoints =  (125, 8)
# model built, time= 0.017191171646118164
# model minimized, time= 1.024181842803955
# time elapsed =  1.5336060523986816
# negative log marginal likelihood = 8.329751072898645
# ---------------
# glac1d_l71C_ump5_lm30 run number 4
# number of datapoints =  (125, 8)
# model built, time= 0.018164873123168945
# model minimized, time= 1.0537528991699219
# time elapsed =  1.5694308280944824
# negative log marginal likelihood = 9.781243332051616
# ---------------
# glac1d_l71C_ump3_lm7 run number 5
# number of datapoints =  (125, 8)
# model built, time= 0.017497777938842773
# model minimized, time= 1.2356688976287842
# time elapsed =  1.7595248222351074
# negative log marginal likelihood = 9.796933745903502
# ---------------
# glac1d_l71C_ump4_lm40 run number 6
# number of datapoints =  (125, 8)
# model built, time= 0.017299890518188477
# model minimized, time= 0.8986291885375977
# time elapsed =  1.3986458778381348
# negative log marginal likelihood = 9.08743466040643
# ---------------
# glac1d_l71C_ump5_lm10 run number 7
# number of datapoints =  (125, 8)
# model built, time= 0.022867918014526367
# model minimized, time= 1.0674669742584229
# time elapsed =  1.6445276737213135
# negative log marginal likelihood = 9.813444211507829
# ---------------
# glac1d_l71C_ump4_lm50 run number 8
# number of datapoints =  (125, 8)
# model built, time= 0.017649173736572266
# model minimized, time= 1.0236139297485352
# time elapsed =  1.5783820152282715
# negative log marginal likelihood = 9.431712597925994
# ---------------
# glac1d_l71C_ump5_lm9 run number 9
# number of datapoints =  (125, 8)
# model built, time= 0.017271995544433594
# model minimized, time= 0.9441838264465332
# time elapsed =  1.471318006515503
# negative log marginal likelihood = 9.492823289049397
# ---------------
# glac1d_l71C_ump4_lm10 run number 10
# number of datapoints =  (125, 8)
# model built, time= 0.023090839385986328
# model minimized, time= 1.0947260856628418
# time elapsed =  1.5927212238311768
# negative log marginal likelihood = 9.378480103632683
# ---------------
# glac1d_l71C_ump5_lm40 run number 11
# number of datapoints =  (125, 8)
# model built, time= 0.020680904388427734
# model minimized, time= 1.1165187358856201
# time elapsed =  1.6628038883209229
# negative log marginal likelihood = 17.137583832581726
# ---------------
# glac1d_l71C_ump5_lm50 run number 12
# number of datapoints =  (125, 8)
# model built, time= 0.01793980598449707
# model minimized, time= 0.9326498508453369
# time elapsed =  1.4663410186767578
# negative log marginal likelihood = 14.762960213906027
# ---------------
# glac1d_l71C_ump5_lm8 run number 13
# number of datapoints =  (125, 8)
# model built, time= 0.020972013473510742
# model minimized, time= 1.0181567668914795
# time elapsed =  1.5564827919006348
# negative log marginal likelihood = 17.306182900573802
# ---------------
# glac1d_l71C_ump4_lm20 run number 14
# number of datapoints =  (125, 8)
# model built, time= 0.01919102668762207
# model minimized, time= 0.8690130710601807
# time elapsed =  1.3333299160003662
# negative log marginal likelihood = 14.773228874488638
# ---------------
# glac1d_l71C_ump5_lm15 run number 15
# number of datapoints =  (125, 8)
# model built, time= 0.01892399787902832
# model minimized, time= 0.915205717086792
# time elapsed =  1.4448068141937256
# negative log marginal likelihood = 17.21441450063874
# ---------------
# glac1d_l71C_ump4_lm30 run number 16
# number of datapoints =  (125, 8)
# model built, time= 0.017421960830688477
# model minimized, time= 0.8063149452209473
# time elapsed =  1.293848991394043
# negative log marginal likelihood = 16.856418584932015
# ---------------
# glac1d_l71C_ump3_lm9 run number 17
# number of datapoints =  (125, 8)
# model built, time= 0.02072882652282715
# model minimized, time= 0.9302568435668945
# time elapsed =  1.4358527660369873
# negative log marginal likelihood = 16.24342996731839
# ---------------
# glac1d_l71C_ump5_lm7 run number 18
# number of datapoints =  (125, 8)
# model built, time= 0.018762826919555664
# model minimized, time= 1.2050538063049316
# time elapsed =  1.7964818477630615
# negative log marginal likelihood = 14.678652247356652
# ---------------
# glac1d_l71C_ump2_lm5 run number 19
# number of datapoints =  (125, 8)
# model built, time= 0.017938852310180664
# model minimized, time= 0.8708419799804688
# time elapsed =  1.3713080883026123
# negative log marginal likelihood = 16.880071460119723
# ---------------
# glac1d_l71C_ump5_lm3 run number 20
# number of datapoints =  (125, 8)
# model built, time= 0.0175168514251709
# model minimized, time= 0.9177839756011963
# time elapsed =  1.4229049682617188
# negative log marginal likelihood = 16.87051596322283
# ---------------
# glac1d_l71C_ump3_lm8 run number 21
# number of datapoints =  (125, 8)
# model built, time= 0.020457983016967773
# model minimized, time= 0.8825857639312744
# time elapsed =  1.377755880355835
# negative log marginal likelihood = 17.066663662989612
# ---------------
# glac1d_l71C_ump4_lm9 run number 22
# number of datapoints =  (125, 8)
# model built, time= 0.019259929656982422
# model minimized, time= 1.2722208499908447
# time elapsed =  1.8095579147338867
# negative log marginal likelihood = 19.876120124361705
# ---------------
# glac1d_l71C_ump3_lm50 run number 23
# number of datapoints =  (125, 8)
# model built, time= 0.017891883850097656
# model minimized, time= 1.0149989128112793
# time elapsed =  1.522662878036499
# negative log marginal likelihood = 21.186454514559884
# ---------------
# glac1d_l71C_ump3_lm40 run number 24
# number of datapoints =  (125, 8)
# model built, time= 0.017230987548828125
# model minimized, time= 1.0661098957061768
# time elapsed =  1.5443809032440186
# negative log marginal likelihood = 20.885555780786333
# ---------------
# glac1d_l71C_ump2_lm7 run number 25
# number of datapoints =  (125, 8)
# model built, time= 0.02051401138305664
# model minimized, time= 1.1449978351593018
# time elapsed =  1.6728367805480957
# negative log marginal likelihood = 16.59877485026263
# ---------------
# glac1d_l71C_ump2_lm10 run number 26
# number of datapoints =  (125, 8)
# model built, time= 0.02342700958251953
# model minimized, time= 1.097883939743042
# time elapsed =  1.5850417613983154
# negative log marginal likelihood = 20.96599125879466
# ---------------
# glac1d_l71C_ump2_lm30 run number 27
# number of datapoints =  (125, 8)
# model built, time= 0.017372846603393555
# model minimized, time= 1.057023048400879
# time elapsed =  1.5752818584442139
# negative log marginal likelihood = 20.221543500343657
# ---------------
# glac1d_l71C_ump5_lm5 run number 28
# number of datapoints =  (125, 8)
# model built, time= 0.020239830017089844
# model minimized, time= 1.2199628353118896
# time elapsed =  1.7448089122772217
# negative log marginal likelihood = 18.87270097788597
# ---------------
# glac1d_l71C_ump2_lm20 run number 29
# number of datapoints =  (125, 8)
# model built, time= 0.019512176513671875
# model minimized, time= 1.052893877029419
# time elapsed =  1.5684449672698975
# negative log marginal likelihood = 20.698682976251533
# ---------------
# glac1d_l71C_ump3_lm15 run number 30
# number of datapoints =  (125, 8)
# model built, time= 0.017249107360839844
# model minimized, time= 1.039121150970459
# time elapsed =  1.5633049011230469
# negative log marginal likelihood = 20.15100034475725
# ---------------
# glac1d_l71C_ump2_lm3 run number 31
# number of datapoints =  (125, 8)
# model built, time= 0.01925206184387207
# model minimized, time= 1.1174640655517578
# time elapsed =  1.5983269214630127
# negative log marginal likelihood = 20.727469575814908
# ---------------
# glac1d_l71C_ump3_lm30 run number 32
# number of datapoints =  (125, 8)
# model built, time= 0.01844310760498047
# model minimized, time= 1.2647302150726318
# time elapsed =  1.7928719520568848
# negative log marginal likelihood = 20.367938212202887
# ---------------
# glac1d_l71C_ump2_lm15 run number 33
# number of datapoints =  (125, 8)
# model built, time= 0.018767118453979492
# model minimized, time= 0.8533871173858643
# time elapsed =  1.36714506149292
# negative log marginal likelihood = 30.23968118843321
# ---------------
# glac1d_l71C_ump3_lm20 run number 34
# number of datapoints =  (125, 8)
# model built, time= 0.018519163131713867
# model minimized, time= 0.9219341278076172
# time elapsed =  1.4388511180877686
# negative log marginal likelihood = 30.219122790297206
# ---------------
# glac1d_l71C_ump2_lm50 run number 35
# number of datapoints =  (125, 8)
# model built, time= 0.017184972763061523
# model minimized, time= 0.8733651638031006
# time elapsed =  1.3827528953552246
# negative log marginal likelihood = 30.561325574596225
# ---------------
# glac1d_l71C_ump4_lm8 run number 36
# number of datapoints =  (125, 8)
# model built, time= 0.01758885383605957
# model minimized, time= 1.0971887111663818
# time elapsed =  1.6292428970336914
# negative log marginal likelihood = 23.387752302351373
# ---------------
# glac1d_l71C_ump3_lm10 run number 37
# number of datapoints =  (125, 8)
# model built, time= 0.01741504669189453
# model minimized, time= 0.8701889514923096
# time elapsed =  1.3765311241149902
# negative log marginal likelihood = 30.860448637525167
# ---------------
# glac1d_l71C_ump2_lm40 run number 38
# number of datapoints =  (125, 8)
# model built, time= 0.017537832260131836
# model minimized, time= 0.8947358131408691
# time elapsed =  1.3684747219085693
# negative log marginal likelihood = 29.895616205034003
# ---------------
# glac1d_l71C_ump4_lm3 run number 39
# number of datapoints =  (125, 8)
# model built, time= 0.019624948501586914
# model minimized, time= 0.8943240642547607
# time elapsed =  1.3999359607696533
# negative log marginal likelihood = 28.374686552444842
# ---------------
# glac1d_l71C_ump3_lm5 run number 40
# number of datapoints =  (125, 8)
# model built, time= 0.018040180206298828
# model minimized, time= 0.8968219757080078
# time elapsed =  1.417011022567749
# negative log marginal likelihood = 30.505137735215484
# ---------------
# glac1d_l71C_ump4_lm7 run number 41
# number of datapoints =  (125, 8)
# model built, time= 0.019408226013183594
# model minimized, time= 0.8370978832244873
# time elapsed =  1.36661696434021
# negative log marginal likelihood = 28.495167117458436
# ---------------
# glac1d_l71C_ump2_lm9 run number 42
# number of datapoints =  (125, 8)
# model built, time= 0.01769113540649414
# model minimized, time= 0.870046854019165
# time elapsed =  1.3874621391296387
# negative log marginal likelihood = 31.766711838245854
# ---------------
# glac1d_l71C_ump2_lm8 run number 43
# number of datapoints =  (125, 8)
# model built, time= 0.01772904396057129
# model minimized, time= 0.8496639728546143
# time elapsed =  1.3455300331115723
# negative log marginal likelihood = 29.728172296033037
